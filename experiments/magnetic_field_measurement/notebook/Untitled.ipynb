# %%
from godirect import GoDirect

# %%
test=GoDirect(use_ble=False, use_usb=True)

# %%
devices=test.list_devices()

# %%
devices

# %%
devices[0].open()
sensors=devices[0].list_sensors()

# %%
sensors
# Out:
# {1: <godirect.sensor.GoDirectSensor at 0x7fa94db198d0>,
#  2: <godirect.sensor.GoDirectSensor at 0x7fa96c7d2690>,
#  3: <godirect.sensor.GoDirectSensor at 0x7fa94dba3650>,
#  4: <godirect.sensor.GoDirectSensor at 0x7fa94dba3850>,
#  5: <godirect.sensor.GoDirectSensor at 0x7fa94dbf16d0>,
#  6: <godirect.sensor.GoDirectSensor at 0x7fa94d74e990>}

# %%
devices[0].start(600)
# Out:
# True

# %%
devices[0].read()
# Out:
# True

# %%
sensors[1]

# %%
print(sensors[1].values)
# Out:
# [0.02994599938392639]
